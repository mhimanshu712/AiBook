# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('../DATA/00-puppy.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
#Matplot --->  RGB
#CV2  ---> BGR
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img2 = cv2.imread('../DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
img2.shape
# Out:
# (1300, 1950)

# %%
# OpenCv resize expects (y,x)
# Yeah its pretty messed up

img_r = cv2.resize(img,(150,100))

# Resize by ratio
#img_r = cv2.resize(img,(0,0),img,0.5,0.5)

plt.imshow(img_r)

# %%
# Flipping 0-vert 1-hor  -1-both
img = cv2.flip(img,0)

# %%
cv2.imwrite('new_dog.jpg',img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(img)
